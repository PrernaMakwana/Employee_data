# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
document='''A paragraph is a series of sentences that are organized and coherent, and are all related to a single topic. Almost every piece of writing you do that is longer than a few sentences should be organized into paragraphs. This is because paragraphs show a reader where the subdivisions of an essay begin and end, and thus help the reader see the organization of the essay and grasp its main points.

Paragraphs can contain many different kinds of information. A paragraph could contain a series of brief examples or a single long illustration of a general point. It might describe a place, character, or process; narrate a series of events; compare or contrast two or more things; classify items into categories; or describe causes and effects. Regardless of the kind of information they contain, all paragraphs share certain characteristics. One of the most important of these is a topic sentence.'''

# %%
split_words=document.split()
split_words
# Out:
# ['A',
#  'paragraph',
#  'is',
#  'a',
#  'series',
#  'of',
#  'sentences',
#  'that',
#  'are',
#  'organized',
#  'and',
#  'coherent,',
#  'and',
#  'are',
#  'all',
#  'related',
#  'to',
#  'a',
#  'single',
#  'topic.',
#  'Almost',
#  'every',
#  'piece',
#  'of',
#  'writing',
#  'you',
#  'do',
#  'that',
#  'is',
#  'longer',
#  'than',
#  'a',
#  'few',
#  'sentences',
#  'should',
#  'be',
#  'organized',
#  'into',
#  'paragraphs.',
#  'This',
#  'is',
#  'because',
#  'paragraphs',
#  'show',
#  'a',
#  'reader',
#  'where',
#  'the',
#  'subdivisions',
#  'of',
#  'an',
#  'essay',
#  'begin',
#  'and',
#  'end,',
#  'and',
#  'thus',
#  'help',
#  'the',
#  'reader',
#  'see',
#  'the',
#  'organization',
#  'of',
#  'the',
#  'essay',
#  'and',
#  'grasp',
#  'its',
#  'main',
#  'points.',
#  'Paragraphs',
#  'can',
#  'contain',
#  'many',
#  'different',
#  'kinds',
#  'of',
#  'information.',
#  'A',
#  'paragraph',
#  'could',
#  'contain',
#  'a',
# ...

# %%
len(split_words)
# Out:
# 150

# %%
tokens=word_tokenize(document)
print(tokens)
len(tokens)
# Out:
# ['A', 'paragraph', 'is', 'a', 'series', 'of', 'sentences', 'that', 'are', 'organized', 'and', 'coherent', ',', 'and', 'are', 'all', 'related', 'to', 'a', 'single', 'topic', '.', 'Almost', 'every', 'piece', 'of', 'writing', 'you', 'do', 'that', 'is', 'longer', 'than', 'a', 'few', 'sentences', 'should', 'be', 'organized', 'into', 'paragraphs', '.', 'This', 'is', 'because', 'paragraphs', 'show', 'a', 'reader', 'where', 'the', 'subdivisions', 'of', 'an', 'essay', 'begin', 'and', 'end', ',', 'and', 'thus', 'help', 'the', 'reader', 'see', 'the', 'organization', 'of', 'the', 'essay', 'and', 'grasp', 'its', 'main', 'points', '.', 'Paragraphs', 'can', 'contain', 'many', 'different', 'kinds', 'of', 'information', '.', 'A', 'paragraph', 'could', 'contain', 'a', 'series', 'of', 'brief', 'examples', 'or', 'a', 'single', 'long', 'illustration', 'of', 'a', 'general', 'point', '.', 'It', 'might', 'describe', 'a', 'place', ',', 'character', ',', 'or', 'process', ';', 'narrate', 'a', 'series', 'of', '
# ...

# %%
#stopword removal
from nltk.corpus import stopwords
nltk.download('stopwords')
#punctuation removal
from string import punctuation
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
english_stopwords=stopwords.words("english")
len(english_stopwords)
# Out:
# 179

# %%
#clean_token=[]
#for token in tokens:
# if token not in english_stopwords:
#   clean_token.append(token)
# Out:
# ['A', 'paragraph', 'series', 'sentences', 'organized', 'coherent', ',', 'related', 'single', 'topic', '.', 'Almost', 'every', 'piece', 'writing', 'longer', 'sentences', 'organized', 'paragraphs', '.', 'This', 'paragraphs', 'show', 'reader', 'subdivisions', 'essay', 'begin', 'end', ',', 'thus', 'help', 'reader', 'see', 'organization', 'essay', 'grasp', 'main', 'points', '.', 'Paragraphs', 'contain', 'many', 'different', 'kinds', 'information', '.', 'A', 'paragraph', 'could', 'contain', 'series', 'brief', 'examples', 'single', 'long', 'illustration', 'general', 'point', '.', 'It', 'might', 'describe', 'place', ',', 'character', ',', 'process', ';', 'narrate', 'series', 'events', ';', 'compare', 'contrast', 'two', 'things', ';', 'classify', 'items', 'categories', ';', 'describe', 'causes', 'effects', '.', 'Regardless', 'kind', 'information', 'contain', ',', 'paragraphs', 'share', 'certain', 'characteristics', '.', 'One', 'important', 'topic', 'sentence', '.']
# 100

# %%
clean_token=[token for token in clean_token if token not in punctuation]
print(clean_token)
len(clean_token)
# Out:
# ['A', 'paragraph', 'series', 'sentences', 'organized', 'coherent', 'related', 'single', 'topic', 'Almost', 'every', 'piece', 'writing', 'longer', 'sentences', 'organized', 'paragraphs', 'This', 'paragraphs', 'show', 'reader', 'subdivisions', 'essay', 'begin', 'end', 'thus', 'help', 'reader', 'see', 'organization', 'essay', 'grasp', 'main', 'points', 'Paragraphs', 'contain', 'many', 'different', 'kinds', 'information', 'A', 'paragraph', 'could', 'contain', 'series', 'brief', 'examples', 'single', 'long', 'illustration', 'general', 'point', 'It', 'might', 'describe', 'place', 'character', 'process', 'narrate', 'series', 'events', 'compare', 'contrast', 'two', 'things', 'classify', 'items', 'categories', 'describe', 'causes', 'effects', 'Regardless', 'kind', 'information', 'contain', 'paragraphs', 'share', 'certain', 'characteristics', 'One', 'important', 'topic', 'sentence']
# 83

# %%
from nltk.stem import PorterStemmer

# %%
stemmer=PorterStemmer()
stemmer.stem("studied")
stemmer.stem("playing")
stemmer.stem("feet")
stemmer.stem("wolves")
# Out:
# 'wolv'

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()
lemmatizer.lemmatize("studied","v")
lemmatizer.lemmatize("wolves")
lemmatizer.lemmatize("feet")
# Out:
# 'foot'

# %%
#apply lemmatizer on clean_token
clean_token=[lemmatizer.lemmatize(token) for token in clean_token]
clean_token=[lemmatizer.lemmatize(token,"v") for token in clean_token]
#verbs in past tense such as ed at the end wale words ko nikalne k liye we will add 'v' at the end
clean_token
# Out:
# ['A',
#  'paragraph',
#  'series',
#  'sentence',
#  'organize',
#  'coherent',
#  'relate',
#  'single',
#  'topic',
#  'Almost',
#  'every',
#  'piece',
#  'write',
#  'longer',
#  'sentence',
#  'organize',
#  'paragraph',
#  'This',
#  'paragraph',
#  'show',
#  'reader',
#  'subdivision',
#  'essay',
#  'begin',
#  'end',
#  'thus',
#  'help',
#  'reader',
#  'see',
#  'organization',
#  'essay',
#  'grasp',
#  'main',
#  'point',
#  'Paragraphs',
#  'contain',
#  'many',
#  'different',
#  'kind',
#  'information',
#  'A',
#  'paragraph',
#  'could',
#  'contain',
#  'series',
#  'brief',
#  'example',
#  'single',
#  'long',
#  'illustration',
#  'general',
#  'point',
#  'It',
#  'might',
#  'describe',
#  'place',
#  'character',
#  'process',
#  'narrate',
#  'series',
#  'event',
#  'compare',
#  'contrast',
#  'two',
#  'thing',
#  'classify',
#  'item',
#  'category',
#  'describe',
#  'cause',
#  'effect',
#  'Regardless',
#  'kind',
#  'information',
#  'contain',
# ...

# %%
len(clean_token)
# Out:
# 83

# %%
#function for preprocessing
def preprocess_doc(document):
  tokens=word_tokenize(document.lower())
  clean_tokens=[token for token in tokens if token not in english_stopwords]
  clean_tokens=[token for token in clean_tokens if token not in punctuation]
  clean_tokens=[lemmatizer.lemmatize(token) for token in clean_tokens]
  clean_tokens=[lemmatizer.lemmatize(token,"v") for token in clean_tokens]
  return clean_tokens

# %%
document_2="""  Shahid Kapoor was born in New Delhi on 25 February 1981 to actor Pankaj Kapur and actor-dancer Neelima Azeem.[1][2] His parents divorced when he was three years old; his father shifted to Mumbai (and married the actress Supriya Pathak) and Kapoor continued living in Delhi with his mother and maternal grandparents.[3][4] His grandparents were journalists for the Russian magazine Sputnik, and Kapoor was particularly fond of his grandfather: "He would walk me to school every single day. He would talk to me about Dad, with whom he shared a great relationship, and read out his letters to me."[3] His father, who was then a struggling actor in Mumbai, would visit Kapoor only once a year on his birthday.[3] When Kapoor was 10, his mother, who was working as a dancer, moved to Mumbai to work as an actress.[3]"""

# %%
#now we pass the data/ document 2 to the above function created
clean_tokens2=preprocess_doc(document_2)
clean_tokens2
# Out:
# ['shahid',
#  'kapoor',
#  'bear',
#  'new',
#  'delhi',
#  '25',
#  'february',
#  '1981',
#  'actor',
#  'pankaj',
#  'kapur',
#  'actor-dancer',
#  'neelima',
#  'azeem',
#  '1',
#  '2',
#  'parent',
#  'divorce',
#  'three',
#  'year',
#  'old',
#  'father',
#  'shift',
#  'mumbai',
#  'marry',
#  'actress',
#  'supriya',
#  'pathak',
#  'kapoor',
#  'continue',
#  'live',
#  'delhi',
#  'mother',
#  'maternal',
#  'grandparent',
#  '3',
#  '4',
#  'grandparent',
#  'journalist',
#  'russian',
#  'magazine',
#  'sputnik',
#  'kapoor',
#  'particularly',
#  'fond',
#  'grandfather',
#  '``',
#  'would',
#  'walk',
#  'school',
#  'every',
#  'single',
#  'day',
#  'would',
#  'talk',
#  'dad',
#  'share',
#  'great',
#  'relationship',
#  'read',
#  'letter',
#  '``',
#  '3',
#  'father',
#  'struggle',
#  'actor',
#  'mumbai',
#  'would',
#  'visit',
#  'kapoor',
#  'year',
#  'birthday',
#  '3',
#  'kapoor',
#  '10',
#  'mother',
#  'work',
#  'dancer',
#  'move',
#  'mumbai',
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#here we are tagging the 1st paragraph that we passed previously for preprocessing
pos_tokens=nltk.pos_tag(clean_token)
print(pos_tokens)
# Out:
# [('A', 'DT'), ('paragraph', 'NN'), ('series', 'NN'), ('sentence', 'NN'), ('organize', 'JJ'), ('coherent', 'NN'), ('relate', 'NN'), ('single', 'JJ'), ('topic', 'NN'), ('Almost', 'NNP'), ('every', 'DT'), ('piece', 'NN'), ('write', 'RB'), ('longer', 'RBR'), ('sentence', 'NN'), ('organize', 'VB'), ('paragraph', 'NN'), ('This', 'DT'), ('paragraph', 'NN'), ('show', 'NN'), ('reader', 'NN'), ('subdivision', 'NN'), ('essay', 'VBP'), ('begin', 'JJ'), ('end', 'NN'), ('thus', 'RB'), ('help', 'NN'), ('reader', 'VB'), ('see', 'VB'), ('organization', 'NN'), ('essay', 'VB'), ('grasp', 'NN'), ('main', 'JJ'), ('point', 'NN'), ('Paragraphs', 'NNP'), ('contain', 'VBP'), ('many', 'JJ'), ('different', 'JJ'), ('kind', 'NN'), ('information', 'NN'), ('A', 'NNP'), ('paragraph', 'NN'), ('could', 'MD'), ('contain', 'VB'), ('series', 'NN'), ('brief', 'NN'), ('example', 'NN'), ('single', 'JJ'), ('long', 'RB'), ('illustration', 'NN'), ('general', 'JJ'), ('point', 'NN'), ('It', 'PRP'), ('might', 'MD'), ('describe',
# ...

# %%
#now we want only nouns from 1st paragraph, so now lets iterate to find out nouns
for element in pos_tokens:
  if element[1] in ["NN","NNS","NNP","NNPS"]:
    print(element[0])
# Out:
# paragraph
# series
# sentence
# coherent
# relate
# topic
# Almost
# piece
# sentence
# paragraph
# paragraph
# show
# reader
# subdivision
# end
# help
# organization
# grasp
# point
# Paragraphs
# kind
# information
# A
# paragraph
# series
# brief
# example
# illustration
# point
# place
# character
# process
# series
# event
# contrast
# thing
# classify
# describe
# cause
# effect
# Regardless
# kind
# information
# contain
# paragraph
# share
# topic
# sentence

# %%
#for paragraph 2
pos_tokens2=nltk.pos_tag(clean_tokens2)
print(pos_tokens2)
#here NN,NNS,NNP,NNPS are noun. you cn google it to find different noun tags
for element in pos_tokens2:
  if element[1] in ["NN","NNS","NNP","NNPS"]:
    print(element[0])
# Out:
# [('shahid', 'JJ'), ('kapoor', 'NNS'), ('bear', 'VBP'), ('new', 'JJ'), ('delhi', 'NN'), ('25', 'CD'), ('february', 'JJ'), ('1981', 'CD'), ('actor', 'NN'), ('pankaj', 'NN'), ('kapur', 'VB'), ('actor-dancer', 'JJ'), ('neelima', 'NNS'), ('azeem', 'VBP'), ('1', 'CD'), ('2', 'CD'), ('parent', 'NN'), ('divorce', 'NN'), ('three', 'CD'), ('year', 'NN'), ('old', 'JJ'), ('father', 'NN'), ('shift', 'NN'), ('mumbai', 'NN'), ('marry', 'NN'), ('actress', 'NN'), ('supriya', 'NN'), ('pathak', 'NN'), ('kapoor', 'NN'), ('continue', 'VBP'), ('live', 'JJ'), ('delhi', 'NN'), ('mother', 'RBR'), ('maternal', 'JJ'), ('grandparent', 'NN'), ('3', 'CD'), ('4', 'CD'), ('grandparent', 'JJ'), ('journalist', 'NN'), ('russian', 'JJ'), ('magazine', 'NN'), ('sputnik', 'JJ'), ('kapoor', 'VBZ'), ('particularly', 'RB'), ('fond', 'JJ'), ('grandfather', 'NN'), ('``', '``'), ('would', 'MD'), ('walk', 'VB'), ('school', 'NN'), ('every', 'DT'), ('single', 'JJ'), ('day', 'NN'), ('would', 'MD'), ('talk', 'VB'), ('dad', 'JJ'), ('
# ...

# %% [markdown]
# NAME ENTITY RECOGNITION **bold text**

# %%
import spacy

# %%
#load a pretrained model from spacy
model=spacy.load("en_core_web_sm")

# %%
clean_document=" ".join(clean_token)
print(clean_document)
#spacy model accept stringor document but clean tokens are in list format
#so we need to convert it to string before passing to model
result=model(clean_document)
#result: it will show normal paragraph text
for entity in result.ents:
  print(entity,entity.label_)
# Out:
# A paragraph series sentence organize coherent relate single topic Almost every piece write longer sentence organize paragraph This paragraph show reader subdivision essay begin end thus help reader see organization essay grasp main point Paragraphs contain many different kind information A paragraph could contain series brief example single long illustration general point It might describe place character process narrate series event compare contrast two thing classify item category describe cause effect Regardless kind information contain paragraph share certain characteristic One important topic sentence
# Paragraphs PERSON
# two CARDINAL
# One CARDINAL

# %%
clean_document_2=" ".join(clean_token)
print(clean_document_2)
#spacy model accept stringor document but clean tokens are in list format
#so we need to convert it to string before passing to model
result=model(clean_document_2)
#result: it will show normal paragraph text
for entity in result.ents:
  print(entity,entity.label_)
# Out:
# A paragraph series sentence organize coherent relate single topic Almost every piece write longer sentence organize paragraph This paragraph show reader subdivision essay begin end thus help reader see organization essay grasp main point Paragraphs contain many different kind information A paragraph could contain series brief example single long illustration general point It might describe place character process narrate series event compare contrast two thing classify item category describe cause effect Regardless kind information contain paragraph share certain characteristic One important topic sentence
# Paragraphs PERSON
# two CARDINAL
# One CARDINAL

# %% [markdown]
# WORD CLOUD: CLOUD IMAGE

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc=WordCloud(width=800,height=900,
             background_color="red",
             min_font_size=8)

wc.generate(clean_document)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
wc=WordCloud(width=1000,height=900,
             background_color="black",
             min_font_size=12)

wc.generate(clean_document_2)
plt.imshow(wc)
plt.axis("off")
plt.show()
